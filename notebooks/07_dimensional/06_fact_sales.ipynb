# %% [markdown]
# # Dimensional — Fact Sales Table
#
# Build `globalmart.gold.fact_sales` from **delivered** order items with FKs to all four dimensions. Validates row count, revenue, and non-null FKs.

# %%
import sys
import importlib

notebook_path = dbutils.notebook.entry_point.getDbutils().notebook().getContext().notebookPath().get()
REPO_ROOT = notebook_path.split("/notebooks/")[0]
if REPO_ROOT not in sys.path:
    sys.path.insert(0, REPO_ROOT)

# Reload dependency modules first (fact_sales imports customer_dim + product_dim).
import src.dimensional.customer_dim as customer_dim_module
import src.dimensional.product_dim as product_dim_module
import src.dimensional.fact_sales as fact_module

importlib.reload(customer_dim_module)
importlib.reload(product_dim_module)
importlib.reload(fact_module)

from src.dimensional.fact_sales import (
    FactSalesConfig,
    build_fact_sales,
    validate_fact_sales,
    run_fact_sales,
    prepare_dimensions_for_fact,
    diagnose_fact_join_gaps,
)
from src.ingestion.idempotent_loader import save_run_report_to_volume

config = FactSalesConfig()
print("Loaded customer_dim from:", customer_dim_module.__file__)
print("Loaded fact_sales from:", fact_module.__file__)
assert hasattr(customer_dim_module, "ensure_delivered_order_customers_in_dim"), (
    "Missing ensure_delivered_order_customers_in_dim — Repos → Pull latest, then re-run this cell."
)

# %%
prep = prepare_dimensions_for_fact(spark, config)
print("Dimension prep:", prep)
print("Join gaps (before build):", diagnose_fact_join_gaps(spark, config))

fact = build_fact_sales(spark, config)
fact.write.format("delta").mode("overwrite").saveAsTable(config.target_table)
print("Fact rows:", spark.table(config.target_table).count())
display(spark.table(config.target_table).limit(10))

# %%
validation = validate_fact_sales(spark, spark.table(config.target_table), config)
print(validation)

# %%
import json

report = run_fact_sales(spark, config)
print(json.dumps(report, indent=2, default=str))
try:
    save_run_report_to_volume(
        report,
        dbutils,
        "/Volumes/globalmart/metadata/run_reports/dimensional_fact_sales.json",
    )
except Exception as exc:
    print("Volume save skipped:", exc)
