# %% [markdown]
# # Gold observability — secure views
#
# Column masking on customers and row-level filter on fact sales via `metadata.user_state_access`.

# %%
import sys, importlib, json
REPO_ROOT = dbutils.notebook.entry_point.getDbutils().notebook().getContext().notebookPath().get().split("/notebooks/")[0]
if REPO_ROOT not in sys.path: sys.path.insert(0, REPO_ROOT)
import src.gold_observability.secure_views as sv
importlib.reload(sv)
from src.gold_observability.secure_views import demo_secure_views
from src.ingestion.idempotent_loader import save_run_report_to_volume

report = demo_secure_views(spark)
save_run_report_to_volume(
    report,
    dbutils,
    "/Volumes/globalmart/metadata/run_reports/gold_secure_views.json",
)
print(json.dumps(report, indent=2))
